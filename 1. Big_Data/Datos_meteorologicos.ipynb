# %%
import pandas as pd

# %%
df = pd.read_csv('DatosEstacion2020-01-30.csv')

# %%
df
# Out:
#            Tiempo Sistema Bar Trend  Next Record  Barometer  \
# 0     2020-01-30 00:00:00         O         1408      29919
# 1     2020-01-30 00:01:00         O         1409      29918
# 2     2020-01-30 00:02:00         O         1410      29919
# 3     2020-01-30 00:03:00         O         1411      29919
# 4     2020-01-30 00:04:00         O         1412      29918
# ...                   ...       ...          ...        ...
# 1435  2020-01-30 23:55:00         O          283      29895
# 1436  2020-01-30 23:56:00         O          284      29898
# 1437  2020-01-30 23:57:00         O          285      29898
# 1438  2020-01-30 23:58:00         O          286      29898
# 1439  2020-01-30 23:59:00         O          287      29898
#
#       Inside Temperature  Inside Humidity  Outside Temperature  Wind Speed  \
# 0                    699               62                  632           0
# 1                    699               62                  632           0
# 2                    699               62                  632           1
# 3                    699               62                  632           0
# 4                    699               62                  632           0
# ...                  ...              ...                  ...         ...
# 1435                 715               61                  641           2
# 1436                 715               61                  641           0
# 1437                 714               61                  640           1
# 1438                 714               61                  640           1
# 1439                 713               61                  639           1
#
#       10 Min Avg Wind Speed  Wind Direction  ...  Soil & Leaf Alarms  \
# 0                         1             234  ...                   0
# 1                         1             234  ...                   0
# 2                         1             234  ...                   0
# 3                         1             234  ...                   0
# 4                         1             234  ...                   0
# ...                     ...             ...  ...                 ...
# 1435                      3             238  ...                   0
# 1436                      3             238  ...                   0
# 1437                      2             238  ...                   0
# 1438                      2             238  ...                   0
# 1439                      2             238  ...                   0
#
#       Transmitter Battery Status  Console Battery Voltage  Forecast Icons  \
# 0                              0                      818               6
# 1                              0                      818               6
# 2                              0                      818               6
# 3                              0                      818               6
# 4                              0                      818               6
# ...                          ...                      ...             ...
# 1435                           0                      818               6
# 1436                           0                      818               6
# 1437                           0                      818               6
# 1438                           0                      818               6
# 1439                           0                      818               6
#
#       Forecast Rule number  Time of Sunrise  Time of Sunset  <LF> = 0x0A  \
# 0                       45              618            1809           10
# 1                       45              618            1809           10
# 2                       45              618            1809           10
# 3                       75              618            1809           10
# 4                       75              618            1809           10
# ...                    ...              ...             ...          ...
# 1435                    45              618            1810           10
# 1436                    45              618            1810           10
# 1437                    45              618            1810           10
# 1438                    45              618            1810           10
# 1439                    45              618            1810           10
#
#       <CR> = 0x0D    CRC
# 0              13   7814
# 1              13  33628
# 2              13  61750
# 3              13  15077
# 4              13  37341
# ...           ...    ...
# 1435           13  35992
# 1436           13  34903
# 1437           13  54698
# 1438           13  52955
# 1439           13   2951
#
# [1440 rows x 42 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Tiempo Sistema               1440 non-null   object
#  1   Bar Trend                    1440 non-null   object
#  2   Next Record                  1440 non-null   int64
#  3   Barometer                    1440 non-null   int64
#  4   Inside Temperature           1440 non-null   int64
#  5   Inside Humidity              1440 non-null   int64
#  6   Outside Temperature          1440 non-null   int64
#  7   Wind Speed                   1440 non-null   int64
#  8   10 Min Avg Wind Speed        1440 non-null   int64
#  9   Wind Direction               1440 non-null   int64
#  10  Extra Temperatures           1440 non-null   int64
#  11  Soil Temperatures            1440 non-null   int64
#  12  Leaf Temperatures            1440 non-null   int64
#  13  Outside Humidity             1440 non-null   int64
#  14  Extra Humidties              1440 non-null   int64
#  15  Rain Rate                    1440 non-null   int64
#  16  UV                           1440 non-null   int64
#  17  Solar Radiation              1440 non-null   int64
#  18  Storm Rain                   1440 non-null   int64
#  19  Start Date of current Storm  1440 non-null   int64
#  20  Day Rain                     1440 non-null   int64
#  21  Month Rain                   1440 non-null   int64
#  22  Year Rain                    1440 non-null   int64
#  23  Day ET                       1440 non-null   int64
#  24  Month ET                     1440 non-null   int64
#  25  Year ET                      1440 non-null   int64
#  26  Soil Moistures               1440 non-null   int64
#  27  Leaf Wetnesses               1440 non-null   int64
#  28  Inside Alarms                1440 non-null   int64
#  29  Rain Alarms                  1440 non-null   int64
#  30  Outside Alarms               1440 non-null   int64
#  31  Extra Temp/Hum Alarms        1440 non-null   int64
#  32  Soil & Leaf Alarms           1440 non-null   int64
#  33  Transmitter Battery Status   1440 non-null   int64
#  34  Console Battery Voltage      1440 non-null   int64
#  35  Forecast Icons               1440 non-null   int64
#  36  Forecast Rule number         1440 non-null   int64
#  37  Time of Sunrise              1440 non-null   int64
#  38  Time of Sunset               1440 non-null   int64
#  39  <LF> = 0x0A                  1440 non-null   int64
#  40  <CR> = 0x0D                  1440 non-null   int64
#  41  CRC                          1440 non-null   int64
# dtypes: int64(40), object(2)
# memory usage: 472.6+ KB

# %%
df.describe()
# Out:
#        Next Record     Barometer  Inside Temperature  Inside Humidity  \
# count  1440.000000   1440.000000         1440.000000      1440.000000
# mean   1615.500694  29924.931250          690.849306        60.516667
# std     794.979171     37.492646           90.315909         2.185555
# min       0.000000  29853.000000          591.000000        56.000000
# 25%    1479.750000  29900.000000          603.000000        58.000000
# 50%    1839.500000  29930.000000          663.500000        62.000000
# 75%    2199.250000  29958.000000          778.000000        62.000000
# max    2559.000000  29987.000000          850.000000        63.000000
#
#        Outside Temperature   Wind Speed  10 Min Avg Wind Speed  \
# count          1440.000000  1440.000000            1440.000000
# mean            625.372222     1.715972               1.681250
# std              66.420400     2.317536               1.891184
# min             543.000000     0.000000               0.000000
# 25%             558.000000     0.000000               0.000000
# 50%             604.000000     1.000000               1.000000
# 75%             697.000000     2.000000               4.000000
# max             740.000000    12.000000               6.000000
#
#        Wind Direction  Extra Temperatures  Soil Temperatures  ...  \
# count     1440.000000              1440.0             1440.0  ...
# mean       219.193750             65535.0            65535.0  ...
# std         55.457018                 0.0                0.0  ...
# min          5.000000             65535.0            65535.0  ...
# 25%        211.000000             65535.0            65535.0  ...
# 50%        236.000000             65535.0            65535.0  ...
# 75%        238.000000             65535.0            65535.0  ...
# max        360.000000             65535.0            65535.0  ...
#
#        Soil & Leaf Alarms  Transmitter Battery Status  \
# count              1440.0                      1440.0
# mean                  0.0                         0.0
# std                   0.0                         0.0
# min                   0.0                         0.0
# 25%                   0.0                         0.0
# 50%                   0.0                         0.0
# 75%                   0.0                         0.0
# max                   0.0                         0.0
#
#        Console Battery Voltage  Forecast Icons  Forecast Rule number  \
# count              1440.000000     1440.000000           1440.000000
# mean                818.409028        5.791667             79.500000
# std                   0.697500        1.117645             44.476103
# min                 817.000000        3.000000             45.000000
# 25%                 818.000000        6.000000             45.000000
# 50%                 819.000000        6.000000             75.000000
# 75%                 819.000000        6.000000             93.000000
# max                 820.000000        7.000000            187.000000
#
#        Time of Sunrise  Time of Sunset  <LF> = 0x0A  <CR> = 0x0D           CRC
# count           1440.0     1440.000000       1440.0       1440.0   1440.000000
# mean             618.0     1809.289583         10.0         13.0  32207.004167
# std                0.0        0.453727          0.0          0.0  19090.968677
# min              618.0     1809.000000         10.0         13.0     52.000000
# 25%              618.0     1809.000000         10.0         13.0  15128.500000
# 50%              618.0     1809.000000         10.0         13.0  32427.500000
# 75%              618.0     1810.000000         10.0         13.0  48693.000000
# max              618.0     1810.000000         10.0         13.0  65513.000000
#
# [8 rows x 40 columns]

# %%
df.keys()
# Out:
# Index(['Tiempo Sistema', 'Bar Trend', 'Next Record', 'Barometer',
#        'Inside Temperature', 'Inside Humidity', 'Outside Temperature',
#        'Wind Speed', '10 Min Avg Wind Speed', 'Wind Direction',
#        'Extra Temperatures', 'Soil Temperatures', 'Leaf Temperatures',
#        'Outside Humidity', 'Extra Humidties', 'Rain Rate', 'UV',
#        'Solar Radiation', 'Storm Rain', 'Start Date of current Storm',
#        'Day Rain', 'Month Rain', 'Year Rain', 'Day ET', 'Month ET', 'Year ET',
#        'Soil Moistures', 'Leaf Wetnesses', 'Inside Alarms', 'Rain Alarms',
#        'Outside Alarms', 'Extra Temp/Hum Alarms', 'Soil & Leaf Alarms',
#        'Transmitter Battery Status', 'Console Battery Voltage',
#        'Forecast Icons', 'Forecast Rule number', 'Time of Sunrise',
#        'Time of Sunset', '<LF> = 0x0A', '<CR> = 0x0D', 'CRC'],
#       dtype='object')

# %%
# Drop columns
cols_to_drop=['Bar Trend', 'Next Record',
    'Inside Temperature', 'Inside Humidity',
    '10 Min Avg Wind Speed', 'Extra Temperatures', 'Soil Temperatures', 'Leaf Temperatures',
    'Extra Humidties', 'Storm Rain', 'Start Date of current Storm',
 #   'Month Rain', 'Year Rain', 'Day ET', 'Month ET', 'Year ET',
    'Day ET', 'Month ET', 'Year ET',
    'Soil Moistures', 'Leaf Wetnesses', 'Inside Alarms', 'Rain Alarms',
    'Outside Alarms', 'Extra Temp/Hum Alarms', 'Soil & Leaf Alarms',
    'Transmitter Battery Status', 'Console Battery Voltage',
    'Forecast Icons', 'Forecast Rule number', 'Time of Sunrise',
    'Time of Sunset', '<LF> = 0x0A', '<CR> = 0x0D', 'CRC']

# %%
import numpy as np
df.drop(cols_to_drop, axis=1, inplace = True)
# Apply basic transformations
df['Tiempo Sistema'] = pd.to_datetime(df['Tiempo Sistema']) - pd.to_timedelta(5,unit='h')
df['Rain Rate'] = df['Rain Rate']*0.2/10. #in units of cm/hour
df['Barometer'] = (df['Barometer']/1000.*(3386.389/100.0)) - (1011.0 - 788.0)
df['Outside Temperature'] = ( df['Outside Temperature']/10. - 32.) * (5.0/9.0)
df.loc[(df['Outside Temperature'] > 50) | (df['Outside Temperature'] < -15)] = np.nan

# %%
df
# Out:
#           Tiempo Sistema   Barometer  Outside Temperature  Wind Speed  \
# 0    2020-01-29 19:00:00  790.173725            17.333333         0.0
# 1    2020-01-29 19:01:00  790.139861            17.333333         0.0
# 2    2020-01-29 19:02:00  790.173725            17.333333         1.0
# 3    2020-01-29 19:03:00  790.173725            17.333333         0.0
# 4    2020-01-29 19:04:00  790.139861            17.333333         0.0
# ...                  ...         ...                  ...         ...
# 1435 2020-01-30 18:55:00  789.360992            17.833333         2.0
# 1436 2020-01-30 18:56:00  789.462583            17.833333         0.0
# 1437 2020-01-30 18:57:00  789.462583            17.777778         1.0
# 1438 2020-01-30 18:58:00  789.462583            17.777778         1.0
# 1439 2020-01-30 18:59:00  789.462583            17.722222         1.0
#
#       Wind Direction  Outside Humidity  Rain Rate   UV  Solar Radiation  \
# 0              234.0              86.0        0.0  0.0              0.0
# 1              234.0              86.0        0.0  0.0              0.0
# 2              234.0              86.0        0.0  0.0              0.0
# 3              234.0              86.0        0.0  0.0              0.0
# 4              234.0              86.0        0.0  0.0              0.0
# ...              ...               ...        ...  ...              ...
# 1435           238.0              83.0        0.0  0.0              0.0
# 1436           238.0              83.0        0.0  0.0              0.0
# 1437           238.0              84.0        0.0  0.0              0.0
# 1438           238.0              84.0        0.0  0.0              0.0
# 1439           238.0              83.0        0.0  0.0              0.0
#
#       Day Rain  Month Rain  Year Rain
# 0          0.0       242.0     6690.0
# 1          0.0       242.0     6690.0
# 2          0.0       242.0     6690.0
# 3          0.0       242.0     6690.0
# 4          0.0       242.0     6690.0
# ...        ...         ...        ...
# 1435       0.0       242.0     6690.0
# 1436       0.0       242.0     6690.0
# 1437       0.0       242.0     6690.0
# 1438       0.0       242.0     6690.0
# 1439       0.0       242.0     6690.0
#
# [1440 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Tiempo Sistema       1440 non-null   datetime64[ns]
#  1   Barometer            1440 non-null   float64
#  2   Outside Temperature  1440 non-null   float64
#  3   Wind Speed           1440 non-null   float64
#  4   Wind Direction       1440 non-null   float64
#  5   Outside Humidity     1440 non-null   float64
#  6   Rain Rate            1440 non-null   float64
#  7   UV                   1440 non-null   float64
#  8   Solar Radiation      1440 non-null   float64
#  9   Day Rain             1440 non-null   float64
#  10  Month Rain           1440 non-null   float64
#  11  Year Rain            1440 non-null   float64
# dtypes: datetime64[ns](1), float64(11)
# memory usage: 135.1 KB
